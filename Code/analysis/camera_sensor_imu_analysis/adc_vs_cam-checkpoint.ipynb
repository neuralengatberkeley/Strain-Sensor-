# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import path_to_repository
from analysis import BallBearingData # class for extracting all data from application and reapplication for ADC, IMU, and Camera Triggers
from analysis import DLC3DBendAngles # class for taking DLC 3d point data and converting to angles 
from analysis import bender_class # class for normalizing adc data, analyzing autobender tests
from analysis_adc_cam import ADC_CAM
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Upload Trials from particpant
# Upload only the parent *date* folder (e.g., "9_19_25").
# If something fails, verify your folder structure matches the "9_19_25" example.

root_dir="CSV Data/11_2_25"
folder_suffix_first  = "B1_adab"       # e.g.  9_19_25_B1_slow
folder_suffix_second = "B2_adab"       # e.g.  9_19_25_B2_slow

#10_28_25 (Tom)
#10_29_25 (bending data might be okay...check...resistance changing)
#11_2_25 (good)
#11_4_25 (good)
#11_7_25 (missing 90 degree cam calibration)

##################### raw adc or imu data for any test ###############################



cam = ADC_CAM(
    root_dir=root_dir,
    path_to_repo=path_to_repository,
    folder_suffix_first=folder_suffix_first,
    folder_suffix_second=folder_suffix_second,
)

first_trials  = cam.load_first()
second_trials = cam.load_second()

n_first  = len(first_trials)
n_second = len(second_trials)

print("Number of first trials:", n_first)
print("Number of second trials:", n_second)
# Out:
# Number of first trials: 3
# Number of second trials: 3

# %% [markdown]
# ## Obtain raw ADC traces for tasks

# %%
adc_trials_first  = cam.extract_adc_dfs_by_trial(first_trials)
adc_trials_second = cam.extract_adc_dfs_by_trial(second_trials)

print("Number of first ADC trials:", len(adc_trials_first))
print("Number of second ADC trials:", len(adc_trials_second))
# Out:
# Number of first ADC trials: 3
# Number of second ADC trials: 3

# %% [markdown]
# ##  Obtain Camera/Protractor Calibration data and plot

# %%
adc_cal_df = cam.extract_calib_means_by_set(
    adc_column="adc_ch3",             # or None to auto-pick
    exclude_name_contains=("C_Block",),
    exclude_sets=(3, 4),
    make_plot=True,
    overlay_mean=True,
    point_alpha=0.008,                 # maybe lower alpha for all points
    point_size=5,                     # smaller points for dense clouds
    jitter=0.25,
    snap_tol_deg=0.5,
    plot_all_data=True,               # <-- THIS plots all ADC samples
    canonical_angles=(0, 22.5, 45, 67.5), #  no 90
)

adc_cal_df
# Out:
#    set                    folder_name  angle_raw_deg  angle_snap_deg  \
# 0    1   2025_11_02_14_12_34_B_calib0            0.0             0.0
# 1    2   2025_11_02_15_29_45_B_calib0            0.0             0.0
# 2    1  2025_11_02_14_13_33_B_calib22           22.0            22.5
# 3    2  2025_11_02_15_30_35_B_calib22           22.0            22.5
# 4    1  2025_11_02_14_14_38_B_calib45           45.0            45.0
# 5    2  2025_11_02_15_31_30_B_calib45           45.0            45.0
# 6    1  2025_11_02_14_16_46_B_calib67           67.0            67.5
# 7    2  2025_11_02_15_32_19_B_calib67           67.0            67.5
# 8    1  2025_11_02_14_18_17_B_calib86           86.0             NaN
# 9    2  2025_11_02_15_33_15_B_calib86           86.0             NaN
#
#   adc_column      adc_mean                                        source_path
# 0    adc_ch3  9.110725e+06  C:\Users\toppe\OneDrive - CSU Maritime Academy...
# ...

# %% [markdown]
# ## Convert ADC values to angles using Camera / Protractor Calibration

# %%
out_cam = cam.calibrate_trials_with_camera(
    adc_trials_first=adc_trials_first,
    adc_trials_second=adc_trials_second,
    adc_column="adc_ch3",
    poly_order=2,
    calib_kwargs=dict(
        adc_column="adc_ch3",
        exclude_name_contains=("C_Block",),
        exclude_sets=(3, 4),
        make_plot=True,
        overlay_mean=True,
        point_alpha=0.25,
        point_size=10,
        jitter=0.25,
        snap_tol_deg=0.5,
    ),
    clamp_theta=True,   # <--- enable clamping
    deg_min=0.0,
    deg_max=90.0,
)

adc_first_theta  = out_cam["adc_trials_first_theta"]
adc_second_theta = out_cam["adc_trials_second_theta"]

# %%
ts = (
    adc_first_theta[0]["timestamp"]
    .astype(str)
    .str.replace(r"\.0$", "", regex=True)
    .str.zfill(12)
)

ts_dt = pd.to_datetime(ts, format="%H%M%S%f", errors="coerce")

adc_first_theta[0]["time_sec"] = (ts_dt - ts_dt.iloc[0]).dt.total_seconds()

adc_first_theta[0]
# Out:
#          timestamp  adc_ch0  adc_ch1  adc_ch2  adc_ch3  trial_index  \
# 0     151211498972        0        0        0  9148233            0
# 1     151211498972        0        0        0  9142772            0
# 2     151211498972        0        0        0  9143113            0
# 3     151211498972        0        0        0  9147038            0
# 4     151211498972        0        0        0  9132703            0
# ...            ...      ...      ...      ...      ...          ...
# 6955  151221494917        0        0        0  9154377            0
# 6956  151221494917        0        0        0  9150964            0
# 6957  151221494917        0        0        0  9150964            0
# 6958  151221494917        0        0        0  9151988            0
# 6959  151221494917        0        0        0  9155571            0
#
#                                             source_path  theta_cam_cal  \
# 0     C:\Users\toppe\OneDrive - CSU Maritime Academy...            0.0
# ...

# %% [markdown]
# ## Plotting the Abduction data.  Note that no camera data present for these tests

# %%
calib_df = out_cam.get("calib_df", None)
coeffs   = out_cam.get("coeffs",  None)

# ---- 1) Skip unless ADAB pairing ----
allowed = {"B1_adab", "B2_adab"}
if {folder_suffix_first, folder_suffix_second} != allowed:
    print("SKIP: suffixes are not exactly {'B1_adab','B2_adab'}")
else:
    # ---- 2) Ensure we have coeffs for set 1 and set 2 ----
    # Prefer coeffs produced by calibrate_trials_with_camera()
    if not isinstance(coeffs, dict):
        coeffs = {}

    # If missing, try to fit from calib_df
    if (1 not in coeffs or 2 not in coeffs):
        if calib_df is None or getattr(calib_df, "empty", True):
            print("WARNING: calib_df is empty/None and coeffs missing for set 1/2 -> cannot compute angles.")
        else:
            # Fit polynomials from calib_df (expects adc_mean and angle_snap_deg)
            poly_order = 2  # match your call
            for s in (1, 2):
                sub = calib_df[(calib_df["set"] == s) & calib_df["angle_snap_deg"].notna()]
                if len(sub) >= (poly_order + 1):
                    x = sub["adc_mean"].to_numpy(dtype=float)
                    y = sub["angle_snap_deg"].to_numpy(dtype=float)
                    coeffs[s] = np.polyfit(x, y, poly_order)

    have_set1 = (1 in coeffs)
    have_set2 = (2 in coeffs)

    if not have_set1 or not have_set2:
        print(f"WARNING: coeffs present for sets: {sorted(coeffs.keys()) if isinstance(coeffs, dict) else coeffs}")
        print("Need coeffs[1] and coeffs[2] to compute theta when theta_cam_cal is missing.")

    # ---- 3) Helper: get theta series; if missing, compute from coeffs + adc_column ----
    def get_theta_series(trial_df, set_id, adc_column="adc_ch3",
                         clamp=True, deg_min=0.0, deg_max=90.0):
        """
        Returns (x, theta) using:
          - trial_df['theta_cam_cal'] if present
          - else apply poly coeffs[set_id] to trial_df[adc_column] to create theta
        """
        if trial_df is None:
            return None

        if hasattr(trial_df, "columns") and ("theta_cam_cal" in trial_df.columns):
            y = np.asarray(trial_df["theta_cam_cal"], dtype=float)
        else:
            if not isinstance(coeffs, dict) or (set_id not in coeffs):
                return None
            if not hasattr(trial_df, "columns") or (adc_column not in trial_df.columns):
                return None
            p = np.poly1d(coeffs[set_id])
            adc_vals = np.asarray(trial_df[adc_column], dtype=float)
            y = p(adc_vals)
            if clamp:
                y = np.clip(y, deg_min, deg_max)

        # x axis preference
        if hasattr(trial_df, "columns") and ("t" in trial_df.columns):
            x = np.asarray(trial_df["t"], dtype=float)
        elif hasattr(trial_df, "columns") and ("time" in trial_df.columns):
            x = np.asarray(trial_df["time"], dtype=float)
        else:
            x = np.arange(len(y))

        return x, y

    # ---- 4) Decide how many rows to plot ----
    n = min(3, len(adc_first_theta), len(adc_second_theta))
    if n == 0:
        print("Nothing to plot: n=0 (your trial lists are empty).")
    else:
        # ---- 5) Plot 3x2 (left uses set 1 cal, right uses set 2 cal) ----
        fig, axes = plt.subplots(3, 2, figsize=(12, 10), sharey=True)

        # hide unused rows
        for r in range(3):
            for c in range(2):
                if r >= n:
                    axes[r, c].axis("off")

        missing = 0
        for i in range(n):
            # Left column: set 1
            ax = axes[i, 0]
            xy = get_theta_series(adc_first_theta[i], set_id=1, adc_column="adc_ch3",
                                  clamp=True, deg_min=0.0, deg_max=90.0)
            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta (set 1)", ha="center", va="center")
            else:
                x, y = xy
                ax.plot(x, y)
            ax.set_title(f"Trial {i+1} — 1st app ({folder_suffix_first}) [set 1 cal]")
            ax.set_ylabel("Angle (deg)")
            ax.set_ylim(0, 90)

            # Right column: set 2
            ax = axes[i, 1]
            xy = get_theta_series(adc_second_theta[i], set_id=2, adc_column="adc_ch3",
                                  clamp=True, deg_min=0.0, deg_max=90.0)
            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta (set 2)", ha="center", va="center")
            else:
                x, y = xy
                ax.plot(x, y)
            ax.set_title(f"Trial {i+1} — 2nd app ({folder_suffix_second}) [set 2 cal]")
            ax.set_ylabel("Angle (deg)")
            ax.set_ylim(0, 90)

        if missing > 0:
            print(f"NOTE: {missing} subplot(s) missing theta. "
                  f"Usually means theta_cam_cal absent AND coeffs for that set missing, "
                  f"or adc_ch3 missing in the trial.")

        fig.suptitle("ADAB: θ per trial using set 1 vs set 2 calibration (3×2)", y=0.98)
        plt.tight_layout()
        plt.show()

# %%
calib_df = out_cam.get("calib_df", None)
coeffs   = out_cam.get("coeffs", None)

# ---- 1) Skip unless ADAB pairing ----
allowed = {"B1_adab", "B2_adab"}
if {folder_suffix_first, folder_suffix_second} != allowed:
    print("SKIP: suffixes are not exactly {'B1_adab','B2_adab'}")
else:
    

    # ---- 2) Ensure we have coeffs for set 1 and set 2 ----
    if not isinstance(coeffs, dict):
        coeffs = {}

    if (1 not in coeffs or 2 not in coeffs):
        if calib_df is None or getattr(calib_df, "empty", True):
            print("WARNING: calib_df is empty/None and coeffs missing for set 1/2 -> cannot compute angles.")
        else:
            poly_order = 2
            for s in (1, 2):
                sub = calib_df[(calib_df["set"] == s) & calib_df["angle_snap_deg"].notna()]
                if len(sub) >= (poly_order + 1):
                    x_fit = sub["adc_mean"].to_numpy(dtype=float)
                    y_fit = sub["angle_snap_deg"].to_numpy(dtype=float)
                    coeffs[s] = np.polyfit(x_fit, y_fit, poly_order)

    # ---- 3) Convert timestamp strings HHMMSSffffff to elapsed seconds ----
    def make_elapsed_time(df, timestamp_col="timestamp"):
        """
        Convert HHMMSSffffff timestamp strings to elapsed seconds.
        Keeps ALL rows; does not collapse repeated timestamps.
        """
        ts = (
            df[timestamp_col]
            .astype(str)
            .str.replace(r"\.0$", "", regex=True)
            .str.strip()
            .str.zfill(12)
        )

        ts_dt = pd.to_datetime(ts, format="%H%M%S%f", errors="coerce")
        elapsed = (ts_dt - ts_dt.iloc[0]).dt.total_seconds()
        return elapsed.to_numpy(dtype=float)

    # ---- 4) Helper: get theta series for ALL rows ----
    def get_theta_series(
        trial_df,
        set_id,
        adc_column="adc_ch3",
        clamp=True,
        deg_min=0.0,
        deg_max=90.0,
    ):
        if trial_df is None or not hasattr(trial_df, "columns"):
            return None

        df = trial_df.copy()

        # ---- y values ----
        if "theta_cam_cal" in df.columns:
            y = pd.to_numeric(df["theta_cam_cal"], errors="coerce").to_numpy(dtype=float)
        else:
            if set_id not in coeffs:
                return None
            if adc_column not in df.columns:
                return None

            adc_vals = pd.to_numeric(df[adc_column], errors="coerce").to_numpy(dtype=float)
            p = np.poly1d(coeffs[set_id])
            y = p(adc_vals)

            if clamp:
                y = np.clip(y, deg_min, deg_max)

        # ---- x values (elapsed time) ----
        if "timestamp" in df.columns:
            x = make_elapsed_time(df)
        else:
            x = np.arange(len(y), dtype=float)

        # ---- keep only finite pairs for plotting ----
        mask = np.isfinite(x) & np.isfinite(y)
        x = x[mask]
        y = y[mask]

        elapsed_sec = float(x[-1] - x[0]) if len(x) > 1 else np.nan
        return x, y, elapsed_sec

    # ---- 5) Decide how many rows to plot ----
    n = min(3, len(adc_first_theta), len(adc_second_theta))
    if n == 0:
        print("Nothing to plot: n=0 (your trial lists are empty).")
    else:
        fig, axes = plt.subplots(3, 2, figsize=(12, 10), sharey=True)

        for r in range(3):
            for c in range(2):
                if r >= n:
                    axes[r, c].axis("off")

        missing = 0

        for i in range(n):
            # ---- LEFT COLUMN (set 1) ----
            ax = axes[i, 0]

            xy = get_theta_series(
                adc_first_theta[i],
                set_id=1,
                adc_column="adc_ch3",
            )

            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta (set 1)", ha="center", va="center")
            else:
                x, y, elapsed_sec = xy
                label = f"elapsed = {elapsed_sec:.2f} s"
                ax.scatter(x, y, s=6, alpha=0.8, label=label)
                ax.legend(loc="best", fontsize=8)

            ax.set_title(f"Trial {i+1} — 1st app ({folder_suffix_first})")
            ax.set_ylabel("Angle (deg)")
            ax.set_xlabel("Time (s)")
            ax.set_ylim(0, 90)

            # ---- RIGHT COLUMN (set 2) ----
            ax = axes[i, 1]

            xy = get_theta_series(
                adc_second_theta[i],
                set_id=2,
                adc_column="adc_ch3",
            )

            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta (set 2)", ha="center", va="center")
            else:
                x, y, elapsed_sec = xy
                label = f"elapsed = {elapsed_sec:.2f} s"
                ax.scatter(x, y, s=6, alpha=0.8, label=label)
                ax.legend(loc="best", fontsize=8)

            ax.set_title(f"Trial {i+1} — 2nd app ({folder_suffix_second})")
            ax.set_ylabel("Angle (deg)")
            ax.set_xlabel("Time (s)")
            ax.set_ylim(0, 90)

        if missing > 0:
            print(f"NOTE: {missing} subplot(s) missing theta.")

        fig.suptitle("ADAB: θ per trial using set 1 vs set 2 calibration", y=0.98)
        plt.tight_layout()
        plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

calib_df = out_cam.get("calib_df", None)
coeffs   = out_cam.get("coeffs", None)

# ---- 1) Skip unless ADAB pairing ----
allowed = {"B1_adab", "B2_adab"}
if {folder_suffix_first, folder_suffix_second} != allowed:
    print("SKIP: suffixes are not exactly {'B1_adab','B2_adab'}")
else:

    # ---- 2) Ensure we have self-calibration coeffs for set 1 and set 2 ----
    if not isinstance(coeffs, dict):
        coeffs = {}

    if (1 not in coeffs or 2 not in coeffs):
        if calib_df is None or getattr(calib_df, "empty", True):
            print("WARNING: calib_df is empty/None and coeffs missing for set 1/2 -> cannot compute angles.")
        else:
            poly_order_self = 2
            for s in (1, 2):
                sub = calib_df[(calib_df["set"] == s) & calib_df["angle_snap_deg"].notna()]
                if len(sub) >= (poly_order_self + 1):
                    x_fit = sub["adc_mean"].to_numpy(dtype=float)
                    y_fit = sub["angle_snap_deg"].to_numpy(dtype=float)
                    coeffs[s] = np.polyfit(x_fit, y_fit, poly_order_self)

    # ---- 3) Build cross-trained coeffs: set 1 shape -> normalized -> rescaled to set 2 endpoints ----
    coeffs_cross_2_from_1 = None
    poly_order_cross = 2
    deg_min = 0.0
    deg_max = 90.0
    cross_new_col = "theta_cam_cal_xtrained"

    if calib_df is None or getattr(calib_df, "empty", True):
        print("WARNING: calib_df is empty/None -> cannot build cross-trained calibration.")
    else:
        sub1 = calib_df[(calib_df["set"] == 1) & calib_df["angle_snap_deg"].notna()].copy()
        sub2 = calib_df[(calib_df["set"] == 2) & calib_df["angle_snap_deg"].notna()].copy()

        if sub1.empty or sub2.empty:
            print("WARNING: missing set 1 or set 2 calibration rows -> cannot build cross-trained calibration.")
        elif len(sub1) < (poly_order_cross + 1):
            print("WARNING: not enough set 1 calibration points for inverse polynomial fit.")
        else:
            # ---- Fit inverse polynomial for set 1: theta -> ADC_1 ----
            theta1 = sub1["angle_snap_deg"].to_numpy(dtype=float)
            adc1   = sub1["adc_mean"].to_numpy(dtype=float)

            coeffs_inv_1 = np.polyfit(theta1, adc1, poly_order_cross)
            q1 = np.poly1d(coeffs_inv_1)

            # ---- Build dense theta grid ----
            theta_grid = np.linspace(deg_min, deg_max, 200)

            # ---- Evaluate set 1 shape in ADC space ----
            adc1_grid = q1(theta_grid)

            # ---- Determine endpoint ADCs using 0 deg and 90 deg from set 1 / set 2 ----
            # Prefer exact snapped endpoints when present; otherwise use polynomial/grid endpoints.
            sub1_0 = sub1[np.isclose(sub1["angle_snap_deg"], deg_min)]
            sub1_90 = sub1[np.isclose(sub1["angle_snap_deg"], deg_max)]
            sub2_0 = sub2[np.isclose(sub2["angle_snap_deg"], deg_min)]
            sub2_90 = sub2[np.isclose(sub2["angle_snap_deg"], deg_max)]

            if len(sub1_0) > 0:
                adc1_at_0 = float(sub1_0["adc_mean"].mean())
            else:
                adc1_at_0 = float(q1(deg_min))

            if len(sub1_90) > 0:
                adc1_at_90 = float(sub1_90["adc_mean"].mean())
            else:
                adc1_at_90 = float(q1(deg_max))

            # For set 2 endpoints, use measured means if available; otherwise fit inverse on set 2 if possible
            if len(sub2_0) > 0:
                adc2_at_0 = float(sub2_0["adc_mean"].mean())
            else:
                if len(sub2) >= (poly_order_cross + 1):
                    coeffs_inv_2 = np.polyfit(
                        sub2["angle_snap_deg"].to_numpy(dtype=float),
                        sub2["adc_mean"].to_numpy(dtype=float),
                        poly_order_cross
                    )
                    q2 = np.poly1d(coeffs_inv_2)
                    adc2_at_0 = float(q2(deg_min))
                else:
                    adc2_at_0 = float(sub2["adc_mean"].max())

            if len(sub2_90) > 0:
                adc2_at_90 = float(sub2_90["adc_mean"].mean())
            else:
                if len(sub2) >= (poly_order_cross + 1):
                    coeffs_inv_2 = np.polyfit(
                        sub2["angle_snap_deg"].to_numpy(dtype=float),
                        sub2["adc_mean"].to_numpy(dtype=float),
                        poly_order_cross
                    )
                    q2 = np.poly1d(coeffs_inv_2)
                    adc2_at_90 = float(q2(deg_max))
                else:
                    adc2_at_90 = float(sub2["adc_mean"].min())

            # ---- Normalize set 1 shape using set 1 endpoints ----
            denom1 = adc1_at_0 - adc1_at_90
            if np.isclose(denom1, 0):
                print("WARNING: set 1 endpoint span is ~0 -> cannot build cross-trained calibration.")
            else:
                adc1_norm_grid = (adc1_grid - adc1_at_90) / denom1

                # ---- Rescale normalized set 1 shape to set 2 endpoint range ----
                adc2_cross_grid = adc2_at_90 + adc1_norm_grid * (adc2_at_0 - adc2_at_90)

                # ---- Fit final cross polynomial: ADC -> theta ----
                coeffs_cross_2_from_1 = np.polyfit(adc2_cross_grid, theta_grid, poly_order_cross)

    # ---- 4) Apply cross-trained coeffs to second-application trials ----
    adc_second_theta_cross = []
    for df in adc_second_theta:
        if df is None or not hasattr(df, "columns"):
            adc_second_theta_cross.append(df)
            continue

        df2 = df.copy()

        if coeffs_cross_2_from_1 is not None and "adc_ch3" in df2.columns:
            adc_vals = pd.to_numeric(df2["adc_ch3"], errors="coerce").to_numpy(dtype=float)
            p_cross = np.poly1d(coeffs_cross_2_from_1)
            theta_cross = p_cross(adc_vals)
            theta_cross = np.clip(theta_cross, deg_min, deg_max)
            df2[cross_new_col] = theta_cross

        adc_second_theta_cross.append(df2)

    # ---- 5) Convert timestamp strings HHMMSSffffff to elapsed seconds ----
    def make_elapsed_time(df, timestamp_col="timestamp"):
        """
        Convert HHMMSSffffff timestamp strings to elapsed seconds.
        Keeps ALL rows; does not collapse repeated timestamps.
        """
        if timestamp_col not in df.columns or len(df) == 0:
            return np.arange(len(df), dtype=float)

        ts = (
            df[timestamp_col]
            .astype(str)
            .str.replace(r"\.0$", "", regex=True)
            .str.strip()
            .str.zfill(12)
        )

        ts_dt = pd.to_datetime(ts, format="%H%M%S%f", errors="coerce")

        if ts_dt.isna().all():
            return np.arange(len(df), dtype=float)

        first_valid_idx = ts_dt.first_valid_index()
        if first_valid_idx is None:
            return np.arange(len(df), dtype=float)

        t0 = ts_dt.loc[first_valid_idx]
        elapsed = (ts_dt - t0).dt.total_seconds()
        return elapsed.to_numpy(dtype=float)

    # ---- 6) Helper: get theta series for plotting ----
    def get_theta_series(
        trial_df,
        *,
        theta_col=None,
        set_id=None,
        adc_column="adc_ch3",
        clamp=True,
        deg_min=0.0,
        deg_max=90.0,
    ):
        """
        Priority:
          1) use theta_col if provided and present
          2) otherwise use self-calibration coeffs via set_id
        """
        if trial_df is None or not hasattr(trial_df, "columns"):
            return None

        df = trial_df.copy()

        # ---- y values ----
        if theta_col is not None and theta_col in df.columns:
            y = pd.to_numeric(df[theta_col], errors="coerce").to_numpy(dtype=float)
        else:
            if set_id is None or set_id not in coeffs:
                return None
            if adc_column not in df.columns:
                return None

            adc_vals = pd.to_numeric(df[adc_column], errors="coerce").to_numpy(dtype=float)
            p = np.poly1d(coeffs[set_id])
            y = p(adc_vals)

            if clamp:
                y = np.clip(y, deg_min, deg_max)

        # ---- x values ----
        if "timestamp" in df.columns:
            x = make_elapsed_time(df)
        else:
            x = np.arange(len(y), dtype=float)

        # ---- finite mask ----
        mask = np.isfinite(x) & np.isfinite(y)
        x = x[mask]
        y = y[mask]

        if len(x) == 0:
            return None

        elapsed_sec = float(x[-1] - x[0]) if len(x) > 1 else np.nan
        return x, y, elapsed_sec

    # ---- 7) Plot 3 columns ----
    n = min(3, len(adc_first_theta), len(adc_second_theta), len(adc_second_theta_cross))
    if n == 0:
        print("Nothing to plot: n=0 (your trial lists are empty).")
    else:
        fig, axes = plt.subplots(3, 3, figsize=(16, 10), sharey=True)

        for r in range(3):
            for c in range(3):
                if r >= n:
                    axes[r, c].axis("off")

        missing = 0

        for i in range(n):
            # ---- COL 1: 1st app using set 1 calibration ----
            ax = axes[i, 0]

            xy = get_theta_series(
                adc_first_theta[i],
                set_id=1,
                adc_column="adc_ch3",
                deg_min=deg_min,
                deg_max=deg_max,
            )

            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta\n(1st app, set 1)", ha="center", va="center")
            else:
                x, y, elapsed_sec = xy
                ax.scatter(x, y, s=6, alpha=0.8, label=f"elapsed = {elapsed_sec:.2f} s")
                ax.legend(loc="best", fontsize=8)

            ax.set_title(f"Trial {i+1} — 1st app\nself-cal ({folder_suffix_first})")
            ax.set_ylabel("Angle (deg)")
            ax.set_xlabel("Time (s)")
            ax.set_ylim(0, 90)

            # ---- COL 2: 2nd app using set 2 calibration ----
            ax = axes[i, 1]

            xy = get_theta_series(
                adc_second_theta[i],
                set_id=2,
                adc_column="adc_ch3",
                deg_min=deg_min,
                deg_max=deg_max,
            )

            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta\n(2nd app, set 2)", ha="center", va="center")
            else:
                x, y, elapsed_sec = xy
                ax.scatter(x, y, s=6, alpha=0.8, label=f"elapsed = {elapsed_sec:.2f} s")
                ax.legend(loc="best", fontsize=8)

            ax.set_title(f"Trial {i+1} — 2nd app\nself-cal ({folder_suffix_second})")
            ax.set_ylabel("Angle (deg)")
            ax.set_xlabel("Time (s)")
            ax.set_ylim(0, 90)

            # ---- COL 3: 2nd app using cross-trained set 1 -> rescaled to set 2 ----
            ax = axes[i, 2]

            xy = get_theta_series(
                adc_second_theta_cross[i],
                theta_col=cross_new_col,
                adc_column="adc_ch3",
                deg_min=deg_min,
                deg_max=deg_max,
            )

            if xy is None:
                missing += 1
                ax.text(0.5, 0.5, "No theta\n(2nd app, xtrained)", ha="center", va="center")
            else:
                x, y, elapsed_sec = xy
                ax.scatter(x, y, s=6, alpha=0.8, label=f"elapsed = {elapsed_sec:.2f} s")
                ax.legend(loc="best", fontsize=8)

            ax.set_title(f"Trial {i+1} — 2nd app\nxtrained 1→2 ({folder_suffix_second})")
            ax.set_ylabel("Angle (deg)")
            ax.set_xlabel("Time (s)")
            ax.set_ylim(0, 20)

        if missing > 0:
            print(f"NOTE: {missing} subplot(s) missing theta.")

        fig.suptitle(
            "ADAB: θ per trial\n"
            "Col 1 = 1st app self-cal | Col 2 = 2nd app self-cal | Col 3 = 2nd app using set 1 shape rescaled to set 2 endpoints",
            y=0.98
        )
        plt.tight_layout()
        plt.show()

    # ---- 8) Optional outputs you can reuse later ----
    out_cross = {
        "coeffs_cross_2_from_1": coeffs_cross_2_from_1,
        "adc_trials_second_theta_cross": adc_second_theta_cross,
    }

# %% [markdown]
# # Get per-trial camera timestamp tables from flir.mat (prefix 'ts*') and DLC 3D point data (two separate dataframes)
#
# This is where you should probably also load the DLC data and combine with cam_trials_first and cam_trials_second.    See my BallBearingClass for examples of how to do that.
#
# ## NOTE:  NO LONGER USING .mat data for timestamp alignment!

# %%
# ---------- 1) FLIR MAT per trial ----------
#cam_trials_first = cam.extract_mat_dfs_by_trial(
#    first_trials,
#    mat_name="flir_data.mat",   # this matches your flir_data_*.mat files
#    prefix="ts",
#    add_labels=True,
#    trial_base=1,
#    set_label="first_cam",
#    include_path=True,
#)

#cam_trials_second = cam.extract_mat_dfs_by_trial(
#    second_trials,
#    mat_name="flir_data.mat",
#    prefix="ts",
#    add_labels=True,
#    trial_base=1,
#    set_label="second_cam",
#    include_path=True,
#)

#print("FLIR first:",  len(cam_trials_first))
#print("FLIR second:", len(cam_trials_second))

# %% [markdown]
# # Get per-trial camera timestamp tables from data_trigger_time csv fles (prefix 'ts*')
#
# This is where you should probably also load the DLC data and combine with cam_trials_first and cam_trials_second.    See my BallBearingClass for examples of how to do that.

# %%
cam_trials_first = cam.extract_trigger_time_dfs_by_trial(
    first_trials,
    add_labels=True,
    trial_base=1,
    set_label="first_cam",
    include_path=True,
)

cam_trials_second = cam.extract_trigger_time_dfs_by_trial(
    second_trials,
    add_labels=True,
    trial_base=1,
    set_label="second_cam",
    include_path=True,
)

print("Trig first:",  len(cam_trials_first))
print("Trig second:", len(cam_trials_second))
# Out:
# Trig first: 3
# Trig second: 3

# %% [markdown]
# # Extract DLC3D point data from csv's

# %%
# ---------- 2) DLC 3D per trial ----------
dlc3d_trials_first = cam.extract_dlc3d_dfs_by_trial(
    first_trials,
    add_labels=True,
    trial_base=1,
    set_label="first_cam",
    include_path=True,
)

dlc3d_trials_second = cam.extract_dlc3d_dfs_by_trial(
    second_trials,
    add_labels=True,
    trial_base=1,
    set_label="second_cam",
    include_path=True,
)

print("DLC first:",  len(dlc3d_trials_first))
print("DLC second:", len(dlc3d_trials_second))
# Out:
# DLC first: 3
# DLC second: 3

# %% [markdown]
# # The DLC3d Data has a multiindex column naming, so need to split up

# %%
# ---------- 3) Coerce DLC columns to MultiIndex using ADC_CAM helper ----------
dlc3d_trials_first  = [cam._coerce_dlc3d_multiindex(d)  for d in dlc3d_trials_first]
dlc3d_trials_second = [cam._coerce_dlc3d_multiindex(d) for d in dlc3d_trials_second]
# Out:
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis_adc_cam.py:1171: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bp = str(body_row[j])
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis_adc_cam.py:1172: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coord = str(coord_row[j])
# ...

# %%
# ---------- 4) Compute MCP + wrist angles (per trial) ----------
dlc3d_trials_first  = [cam._coerce_dlc3d_multiindex(d)  for d in dlc3d_trials_first]
dlc3d_trials_second = [cam._coerce_dlc3d_multiindex(d) for d in dlc3d_trials_second]

aug_first,  tall_first  = cam.compute_dlc3d_angles_by_trial(
    dlc3d_trials_first,  set_label="first_cam",  signed_in_plane=True
)
aug_second, tall_second = cam.compute_dlc3d_angles_by_trial(
    dlc3d_trials_second, set_label="second_cam", signed_in_plane=True
)

print("len(aug_first) vs cam_trials_first:",
      len(aug_first), "vs", len(cam_trials_first))

print("len(aug_second) vs cam_trials_second:",
      len(aug_second), "vs", len(cam_trials_second))
# Out:
# len(aug_first) vs cam_trials_first: 3 vs 3
# len(aug_second) vs cam_trials_second: 3 vs 3

# %% [markdown]
# ## Combine DLC3D bend angles and timestamp data

# %%
# ---------- 5) Attach FLIR timestamps to DLC angle trials ----------
dlc3D_angles_first  = cam.attach_cam_timestamps_to_angles(
    cam_trials_first,
    aug_first,
    time_col_name="timestamp",     # from _mat_to_df
    new_col_name="cam_timestamp",  # name of column in angles dfs
)

dlc3D_angles_second = cam.attach_cam_timestamps_to_angles(
    cam_trials_second,
    aug_second,
    time_col_name="timestamp",
    new_col_name="cam_timestamp",
)

print("len(dlc3D_angles_first):",  len(dlc3D_angles_first))
print("len(dlc3D_angles_second):", len(dlc3D_angles_second))
# Out:
# len(dlc3D_angles_first): 3
# len(dlc3D_angles_second): 3

# %% [markdown]
# ## Filter rows with low likelihood DLC estimation

# %%
# Filter out low-likelihood frames before doing ADC alignment / comparisons
dlc3D_angles_first_filt = cam.filter_angle_trials_by_likelihood(
    dlc3D_angles_first,
    bodyparts=("MCP", "PIP", "hand"),
    min_likelihood=0.45,  # this should be same as IMU data
)

dlc3D_angles_second_filt = cam.filter_angle_trials_by_likelihood(
    dlc3D_angles_second,
    bodyparts=("MCP", "PIP", "hand"),
    min_likelihood=0.45,
)

print(len(dlc3D_angles_first[0]),  len(dlc3D_angles_first_filt[0]))
print(len(dlc3D_angles_second[0]), len(dlc3D_angles_second_filt[0]))
# Out:
# 197 70
# 197 33

# %% [markdown]
# ## Align Timestamps

# %%
# Align FIRST set: DLC MCP angles vs ADC-calibrated angles
merged_first = cam.align_adc_theta_to_dlc_angles_for_set(
    dlc_angle_trials=dlc3D_angles_first_filt,
    adc_theta_trials=adc_first_theta,
    dlc_time_col="cam_timestamp",    # from attach_cam_timestamps_to_angles
    adc_time_col="timestamp",        # column in adc_first_theta
    adc_cols=["theta_cam_cal"],      # or None to attach all ADC columns
    time_unit="ns",                   # <-- try 's' first; use 'ms' if your timestamps are in milliseconds
    tolerance="50ms",
    direction="nearest",
    suffix="_adc",
    keep_time_delta=True,
    drop_unmatched=True,
)

# Align SECOND set
merged_second = cam.align_adc_theta_to_dlc_angles_for_set(
    dlc_angle_trials=dlc3D_angles_second_filt,
    adc_theta_trials=adc_second_theta,
    dlc_time_col="cam_timestamp",
    adc_time_col="timestamp",
    adc_cols=["theta_cam_cal"],
    time_unit="ns",
    tolerance="50ms",
    direction="nearest",
    suffix="_adc",
    keep_time_delta=True,
    drop_unmatched=True,
)

#-----EXAMPLE PLOTTING-------#

trial_idx = 0

# IMU column from alignment step
IMU_COL = "theta_cam_cal_adc"   # your OUT_COL

# DLC 3D angle column (MultiIndex: ('metric','mcp_bend_deg','deg'))
DLC_COL = ("metric", "mcp_bend_deg", "deg")

df = merged_first[trial_idx]

# Extract DLC angle column
dlc_angle = df[DLC_COL]
imu_angle = df[IMU_COL]

# Make plot
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(dlc_angle.values, label="DLC 3D MCP Bend (deg)", color="blue", linewidth=2)
ax.plot(imu_angle.values, label="ADC Bend Angle (deg)", color="orange", linewidth=2)

ax.set_xlabel("Sample Index")
ax.set_ylabel("Angle (deg)")
ax.set_title(f"Trial {trial_idx}: DLC vs IMU Bend Angle (Index Domain)")
ax.grid(True)
#ax.set_ylim(-10, 180)
ax.legend()

plt.show()
# Out:
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis.py:4419: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   cam_small["_t_cam_ns"] = cam_small["t_cam_td"].view("i8")
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis.py:4420: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   enc_small["_t_enc_ns"] = enc_small["t_enc_td"].view("i8")
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis.py:4419: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
# ...

# %%
# Refine FIRST set and plot a few trials
refined_first, summary_first = cam.refine_alignment_by_rmse_for_set(
    merged_trials=merged_first,
    dlc_col=("metric", "mcp_bend_deg", "deg"),
    adc_col="theta_cam_cal_adc",
    max_lag_samples=100, 
    time_col=("_t_cam_td", "", ""),   # or ("cam_timestamp", "", "")
    plot_indices=[0, 1],           # which trials to plot
    set_name="FIRST",
    do_refine=False,                 # <--- NO further alignment
)

print(summary_first)

# Refine SECOND set and plot a few trials
refined_second, summary_second = cam.refine_alignment_by_rmse_for_set(
    merged_trials=merged_second,
    dlc_col=("metric", "mcp_bend_deg", "deg"),
    adc_col="theta_cam_cal_adc",
    max_lag_samples=100, 
    time_col=("_t_cam_td", "", ""),   # or ("cam_timestamp", "", "")
    plot_indices=[0, 1],           # which trials to plot
    set_name="SECOND",
    do_refine=False,                 # <--- NO further alignment
)

print(summary_second)
# Out:
#    trial_index  best_lag_samples   rmse_deg  n_points
# 0            0                 0  76.990449        70
# 1            1                 0  56.195281        23
# 2            2                 0  12.537495         9
#    trial_index  best_lag_samples    rmse_deg  n_points
# 0            0                 0   60.318011        33
# 1            1                 0  121.850918        60
# 2            2                 0   35.272159        95

# %%
cam.plot_abs_error_box_two_sets(
    refined_first=refined_first,
    summary_first=summary_first,
    refined_second=refined_second,
    summary_second=summary_second,
    dlc_col=("metric", "mcp_bend_deg", "deg"),
    adc_rmse_col="theta_cam_cal_adc_rmse",
    trial_indices_first=[0, 1],    # FIRST set: trials 1 & 2 (0-based)
    trial_indices_second=[0, 1],   # SECOND set: trials 1 & 3
    label_first="FIRST",
    label_second="SECOND",
)

# %% [markdown]
# ## New reapplied version
# Blue Boxes
# → Self-calibrated condition
#
# 1st application trials are converted to angle using the 1st calibration curve (their own quadratic fit).
#
# 2nd application trials are converted to angle using the 2nd calibration curve (their own quadratic fit).
#
# Red Boxes
# → Cross-trained / recalibrated condition
#
# We take the 1st calibration curve, convert it to a normalized 0–1 scale using its own min/max ADC.
#
# Then we rescale that normalized calibration curve to the min and max ADC of the 2nd calibration data, producing a second-application-mapped version of the first calibration curve.
#
# This re-mapped calibration curve is used to convert 2nd application trials to angle.

# %% [markdown]
# # Below method could be written as a @staticmethod in analysis_adc_cam.py

# %%
from typing import Optional, Sequence
from analysis_adc_cam import ADC_CAM
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def run_adc_cam_pipeline_for_participant_speed(
    root_dir: str,
    speed_tag: str,
    *,
    path_to_repo: str,
    adc_column: str = "adc_ch3",
    calib_kwargs: Optional[dict] = None,
    time_unit: str = "ns",
    align_tolerance: str = "50ms",
    max_lag_samples: int = 100,  # kept in signature but NOT used for refinement below
    trial_indices_first: Optional[Sequence[int]] = None,
    trial_indices_second: Optional[Sequence[int]] = None,
    min_dlc_likelihood: float = 0.9,
    # NEW: allow specifying canonical calibration angles (deg)
    canonical_angles: Optional[Sequence[float]] = None,
) -> dict:
    """
    Run the full ADC_CAM pipeline for a given participant/date (root_dir)
    and one speed condition (slow, medm, fast, vfas, afap).

    Now also computes a cross-trained calibration for the SECOND application,
    using the first application's calibration shape (blue = self, red = cross).

    Parameters
    ----------
    ...
    min_dlc_likelihood : float, default 0.9
        DLC likelihood threshold for MCP/PIP/hand filtering.
    canonical_angles : sequence of float or None, default None
        Canonical calibration angles (deg) to use inside
        extract_calib_means_by_set. If None, that method's default
        is used (e.g. (0, 22, 45, 67, 90)).
    """

    # 1) Build ADC_CAM for this speed
    folder_suffix_first = f"B1_{speed_tag}"
    folder_suffix_second = f"B2_{speed_tag}"

    cam = ADC_CAM(
        root_dir=root_dir,
        path_to_repo=path_to_repo,
        folder_suffix_first=folder_suffix_first,
        folder_suffix_second=folder_suffix_second,
    )

    # 2) Load raw trials (paths)
    first_trials = cam.load_first()
    second_trials = cam.load_second()

    if len(first_trials) == 0 and len(second_trials) == 0:
        return {
            "abs_err_first": np.array([]),
            "abs_err_second": np.array([]),
            "abs_err_second_cross": np.array([]),
            "summary_first": pd.DataFrame(),
            "summary_second": pd.DataFrame(),
            "summary_second_cross": pd.DataFrame(),  # fixed typo
        }

    # 3) Load ADC CSVs per trial
    adc_first = cam.extract_adc_dfs_by_trial(first_trials)
    adc_second = cam.extract_adc_dfs_by_trial(second_trials)

    # --- NEW: inject canonical_angles into calib_kwargs if provided ---
    if calib_kwargs is None:
        calib_kwargs = {}
    else:
        calib_kwargs = dict(calib_kwargs)  # shallow copy so we don't mutate caller

    if canonical_angles is not None:
        calib_kwargs["canonical_angles"] = tuple(canonical_angles)

    # 4) Camera-based calibration (ADC -> theta), SELF for both sets
    calib_result = cam.calibrate_trials_with_camera(
        adc_trials_first=adc_first,
        adc_trials_second=adc_second,
        adc_column=adc_column,
        poly_order=2,
        calib_kwargs=calib_kwargs,
        clamp_theta=True,
        deg_min=0.0,
        deg_max=90.0,
    )

    calib_df         = calib_result["calib_df"]
    adc_first_theta  = calib_result["adc_trials_first_theta"]
    adc_second_theta = calib_result["adc_trials_second_theta"]

    # 4b) CROSS-trained calibration for second application
    cross_result = cam.reapply_first_calibration_to_second(
        calib_df=calib_df,
        adc_trials_second=adc_second,
        adc_column=adc_column,
        poly_order=2,
        deg_min=0.0,
        deg_max=90.0,
        new_col="theta_cam_cal_xtrained",
        clamp_theta=True,
    )
    adc_second_theta_cross = cross_result["adc_trials_second_theta_cross"]

    # 5) Trigger-time CSV per trial (timestamps)  **REPLACES FLIR MAT**
    cam_trials_first = cam.extract_trigger_time_dfs_by_trial(
        first_trials,
        add_labels=True,
        trial_base=1,
        set_label="first_cam",
        include_path=True,
    )
    cam_trials_second = cam.extract_trigger_time_dfs_by_trial(
        second_trials,
        add_labels=True,
        trial_base=1,
        set_label="second_cam",
        include_path=True,
    )

    # 6) DLC per trial
    dlc3d_trials_first = cam.extract_dlc3d_dfs_by_trial(
        first_trials,
        add_labels=True,
        trial_base=1,
        set_label="first_cam",
        include_path=True,
    )
    dlc3d_trials_second = cam.extract_dlc3d_dfs_by_trial(
        second_trials,
        add_labels=True,
        trial_base=1,
        set_label="second_cam",
        include_path=True,
    )

    # 7) Coerce DLC -> MultiIndex and compute angles
    dlc3d_trials_first  = [cam._coerce_dlc3d_multiindex(d)  for d in dlc3d_trials_first]
    dlc3d_trials_second = [cam._coerce_dlc3d_multiindex(d) for d in dlc3d_trials_second]

    aug_first,  _ = cam.compute_dlc3d_angles_by_trial(
        dlc3d_trials_first,  set_label="first_cam",  signed_in_plane=True
    )
    aug_second, _ = cam.compute_dlc3d_angles_by_trial(
        dlc3d_trials_second, set_label="second_cam", signed_in_plane=True
    )

    # 8) Attach trigger timestamps to DLC angle trials
    dlc3D_angles_first = cam.attach_cam_timestamps_to_angles(
        cam_trials_first,
        aug_first,
        time_col_name="timestamp",
        new_col_name="cam_timestamp",
    )
    dlc3D_angles_second = cam.attach_cam_timestamps_to_angles(
        cam_trials_second,
        aug_second,
        time_col_name="timestamp",
        new_col_name="cam_timestamp",
    )

    # 8b) Filter out low-likelihood DLC rows before alignment
    dlc3D_angles_first = cam.filter_angle_trials_by_likelihood(
        dlc3D_angles_first,
        bodyparts=("MCP", "PIP", "hand"),
        min_likelihood=min_dlc_likelihood,
    )
    dlc3D_angles_second = cam.filter_angle_trials_by_likelihood(
        dlc3D_angles_second,
        bodyparts=("MCP", "PIP", "hand"),
        min_likelihood=min_dlc_likelihood,
    )

    # 9) Align ADC-theta to DLC angles (time-based): SELF calibrations
    merged_first = cam.align_adc_theta_to_dlc_angles_for_set(
        dlc_angle_trials=dlc3D_angles_first,
        adc_theta_trials=adc_first_theta,
        dlc_time_col="cam_timestamp",
        adc_time_col="timestamp",
        adc_cols=["theta_cam_cal"],
        time_unit=time_unit,
        tolerance=align_tolerance,
        direction="nearest",
        suffix="_adc",
        keep_time_delta=True,
        drop_unmatched=True,
    )

    merged_second = cam.align_adc_theta_to_dlc_angles_for_set(
        dlc_angle_trials=dlc3D_angles_second,
        adc_theta_trials=adc_second_theta,
        dlc_time_col="cam_timestamp",
        adc_time_col="timestamp",
        adc_cols=["theta_cam_cal"],
        time_unit=time_unit,
        tolerance=align_tolerance,
        direction="nearest",
        suffix="_adc",
        keep_time_delta=True,
        drop_unmatched=True,
    )

    # 9b) Align ADC-theta to DLC angles (time-based): CROSS-trained calibrations
    merged_second_cross = cam.align_adc_theta_to_dlc_angles_for_set(
        dlc_angle_trials=dlc3D_angles_second,
        adc_theta_trials=adc_second_theta_cross,
        dlc_time_col="cam_timestamp",
        adc_time_col="timestamp",
        adc_cols=["theta_cam_cal_xtrained"],
        time_unit=time_unit,
        tolerance=align_tolerance,
        direction="nearest",
        suffix="_adc",
        keep_time_delta=True,
        drop_unmatched=True,
    )

    # 10) RMSE-based refinement (SELF) -- DISABLED (no further alignment)
    refined_first, summary_first = cam.refine_alignment_by_rmse_for_set(
        merged_trials=merged_first,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_col="theta_cam_cal_adc",
        max_lag_samples=0,  # <- NO lag refinement
        time_col=("_t_cam_td", "", ""),
        plot_indices=None,
        set_name=f"{speed_tag.upper()} FIRST",
        do_refine=False,                 # <--- NO further alignment
    )

    refined_second, summary_second = cam.refine_alignment_by_rmse_for_set(
        merged_trials=merged_second,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_col="theta_cam_cal_adc",
        max_lag_samples=0,  # <- NO lag refinement
        time_col=("_t_cam_td", "", ""),
        plot_indices=None,
        set_name=f"{speed_tag.upper()} SECOND (self)",
        do_refine=False,                 # <--- NO further alignment
    )

    # 10b) RMSE-based refinement (CROSS) -- DISABLED (no further alignment)
    refined_second_cross, summary_second_cross = cam.refine_alignment_by_rmse_for_set(
        merged_trials=merged_second_cross,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_col="theta_cam_cal_xtrained_adc",
        max_lag_samples=0,  # <- NO lag refinement
        time_col=("_t_cam_td", "", ""),
        plot_indices=None,
        set_name=f"{speed_tag.upper()} SECOND (cross)",
    )

    # 11) Collect abs-error distributions using explicit trial indices
    abs_err_first = cam.collect_abs_error_for_set(
        refined_first,
        summary_first,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_rmse_col="theta_cam_cal_adc_rmse",
        trial_indices=trial_indices_first,
        n_best=2,
    )

    abs_err_second = cam.collect_abs_error_for_set(
        refined_second,
        summary_second,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_rmse_col="theta_cam_cal_adc_rmse",
        trial_indices=trial_indices_second,
        n_best=2,
    )

    abs_err_second_cross = cam.collect_abs_error_for_set(
        refined_second_cross,
        summary_second_cross,
        dlc_col=("metric", "mcp_bend_deg", "deg"),
        adc_rmse_col="theta_cam_cal_xtrained_adc_rmse",
        trial_indices=trial_indices_second,
        n_best=2,
    )

    return {
        "refined_first": refined_first,
        "refined_second": refined_second,
        "refined_second_cross": refined_second_cross,

        "abs_err_first": abs_err_first,
        "abs_err_second": abs_err_second,
        "abs_err_second_cross": abs_err_second_cross,
        "summary_first": summary_first,
        "summary_second": summary_second,
        "summary_second_cross": summary_second_cross,
    }

# %%
# -----------------------------------------
# CONFIG: participants, speeds, and trial indices
# -----------------------------------------

participants = [
    {"name": "P1", "root_dir": "CSV Data/11_2_25"},
    {"name": "P2", "root_dir": "CSV Data/11_4_25"},
    {"name": "P3", "root_dir": "CSV Data/11_7_25"},
    #{"name": "P4", "root_dir": "CSV Data/11_16_25"},
]

speed_tags   = ["slow", "medm", "fast", "vfas", "afap"]
speed_titles = ["Slow", "Medm", "Fast", "VFast", "AFAP"]

# Explicit trial indices to use for EACH speed + set
# (You can make this a dict keyed by speed/participant if you want more control.)
trial_indices_first_default  = [0, 1]  # B1_* application
trial_indices_second_default = [0, 1]  # B2_* application

# NEW: DLC likelihood threshold
min_dlc_likelihood = 0.45

# NEW: canonical calibration angles (drop 90°)
canonical_angles = (0, 22, 45, 67)


# -----------------------------------------
# Run pipeline for all (participant, speed)
# -----------------------------------------

results = {}  # (participant_name, speed_tag) -> dict from helper

for p in participants:
    for speed in speed_tags:
        key = (p["name"], speed)
        print(f"Processing {p['name']} - {speed} ...")
        res = run_adc_cam_pipeline_for_participant_speed(
            root_dir=p["root_dir"],
            speed_tag=speed,
            path_to_repo=path_to_repository,
            adc_column="adc_ch3",
            calib_kwargs=None,
            time_unit="ns",
            align_tolerance="50ms",
            max_lag_samples=100,
            trial_indices_first=trial_indices_first_default,
            trial_indices_second=trial_indices_second_default,
            min_dlc_likelihood=min_dlc_likelihood,
            canonical_angles=canonical_angles,   #  NEW
        )
        results[key] = res




# -----------------------------------------
# Build 2×6 summary figure:
# row 1: B1_* (FIRST application)
# row 2: B2_* (SECOND application, self vs cross)
# cols 1–5: per-speed boxplots
# col 6: summary bar (mean abs error vs speed)
# -----------------------------------------

fig, axes = plt.subplots(2, 6, figsize=(24, 8), sharey=True)

def style_boxplot_with_colors(ax, data, labels, colors):
    """
    data  : list of 1D arrays
    labels: list of str, same len as data
    colors: list of matplotlib colors, same len as data
    """
    bp = ax.boxplot(
        data,
        labels=labels,
        showfliers=False,
        patch_artist=True,
    )
    # Color each box individually
    for box, c in zip(bp["boxes"], colors):
        box.set_facecolor(c)
    # Medians black + thick
    for med in bp["medians"]:
        med.set_color("k")
        med.set_linewidth(2.5)
    return bp

# --- row 1: FIRST set (B1_*) ---
for col, (speed, speed_title) in enumerate(zip(speed_tags, speed_titles)):
    ax = axes[0, col]
    data = []
    labels = []
    colors = []

    for p in participants:
        key = (p["name"], speed)
        abs_err = results.get(key, {}).get("abs_err_first", np.array([]))
        if abs_err.size == 0:
            continue
        data.append(abs_err)
        labels.append(p["name"])   # e.g. P1, P2
        colors.append("C0")        # blue for first app

    if data:
        style_boxplot_with_colors(ax, data, labels, colors)
    ax.set_title(f"{speed_title} (1st)")
    if col == 0:
        ax.set_ylabel("Abs error (deg)")
    ax.grid(axis="y", alpha=0.3)

# --- row 2: SECOND set (B2_*), self (blue) vs cross (red) ---
for col, (speed, speed_title) in enumerate(zip(speed_tags, speed_titles)):
    ax = axes[1, col]
    data = []
    labels = []
    colors = []

    for p in participants:
        key = (p["name"], speed)
        abs_self  = results.get(key, {}).get("abs_err_second",        np.array([]))
        abs_cross = results.get(key, {}).get("abs_err_second_cross", np.array([]))

        # Self-calibrated (blue)
        if abs_self.size > 0:
            data.append(abs_self)
            labels.append(f"{p['name']} self")
            colors.append("C0")  # blue

        # Cross-trained (red)
        if abs_cross.size > 0:
            data.append(abs_cross)
            labels.append(f"{p['name']} xtrain")
            colors.append("C3")  # red-ish

    if data:
        style_boxplot_with_colors(ax, data, labels, colors)
    ax.set_title(f"{speed_title} (2nd)")
    if col == 0:
        ax.set_ylabel("Abs error (deg)")
    ax.grid(axis="y", alpha=0.3)

# --- Column 6 (index 5): summary bar plots of mean error per speed ---

x = np.arange(len(speed_tags))

# Row 1 summary: FIRST set (single blue bar per speed)
ax_sum_first = axes[0, 5]
mean_first = []
for speed in speed_tags:
    all_err = []
    for p in participants:
        key = (p["name"], speed)
        abs_err = results.get(key, {}).get("abs_err_first", np.array([]))
        if abs_err.size > 0:
            all_err.append(abs_err)
    if all_err:
        all_err = np.concatenate(all_err)
        mean_first.append(np.nanmean(all_err))
    else:
        mean_first.append(np.nan)

ax_sum_first.bar(x, mean_first, color="C0")
ax_sum_first.set_xticks(x)
ax_sum_first.set_xticklabels(speed_titles, rotation=45)
ax_sum_first.set_ylabel("Mean abs error (deg)")
ax_sum_first.set_title("1st app mean error vs speed")
ax_sum_first.grid(axis="y", alpha=0.3)

# Row 2 summary: SECOND set (blue = self, red = cross)
ax_sum_second = axes[1, 5]

mean_second_self  = []
mean_second_cross = []

for speed in speed_tags:
    all_self  = []
    all_cross = []

    for p in participants:
        key = (p["name"], speed)
        abs_self  = results.get(key, {}).get("abs_err_second",        np.array([]))
        abs_cross = results.get(key, {}).get("abs_err_second_cross", np.array([]))

        if abs_self.size > 0:
            all_self.append(abs_self)
        if abs_cross.size > 0:
            all_cross.append(abs_cross)

    if all_self:
        all_self_concat = np.concatenate(all_self)
        mean_second_self.append(np.nanmean(all_self_concat))
    else:
        mean_second_self.append(np.nan)

    if all_cross:
        all_cross_concat = np.concatenate(all_cross)
        mean_second_cross.append(np.nanmean(all_cross_concat))
    else:
        mean_second_cross.append(np.nan)

width = 0.35
ax_sum_second.bar(x - width/2, mean_second_self,  width=width, color="C0", label="self")
ax_sum_second.bar(x + width/2, mean_second_cross, width=width, color="C3", label="xtrain")

ax_sum_second.set_xticks(x)
ax_sum_second.set_xticklabels(speed_titles, rotation=45)
ax_sum_second.set_ylabel("Mean abs error (deg)")
ax_sum_second.set_title("2nd app mean error vs speed")
ax_sum_second.grid(axis="y", alpha=0.3)
ax_sum_second.legend()

plt.tight_layout()
plt.show()
# Out:
# Processing P1 - slow ...
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis_adc_cam.py:1171: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bp = str(body_row[j])
# C:\Users\toppe\OneDrive - CSU Maritime Academy\Documents\GitHub\Strain-Sensor-\Code\analysis\camera_sensor_imu_analysis\analysis_adc_cam.py:1172: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coord = str(coord_row[j])
# ...

# %% [markdown]
# ## Average Errors Across Speeds and Total Average Error:

# %%
ERROR_THRESH_DEG = 5.0

# --- Build per-speed means (same logic as your bar plots) ---
rows = []
for i, (speed, speed_title) in enumerate(zip(speed_tags, speed_titles)):

    # 1st app (self)
    all_first = []
    # 2nd app (self)
    all_second_self  = []
    # 2nd app (cross)
    all_second_cross = []

    for p in participants:
        key = (p["name"], speed)

        a1  = results.get(key, {}).get("abs_err_first", np.array([]))
        a2s = results.get(key, {}).get("abs_err_second", np.array([]))
        a2x = results.get(key, {}).get("abs_err_second_cross", np.array([]))

        if a1.size > 0:  all_first.append(a1)
        if a2s.size > 0: all_second_self.append(a2s)
        if a2x.size > 0: all_second_cross.append(a2x)

    def _concat_finite(list_of_arrays):
        """Concatenate arrays and keep only finite values."""
        if not list_of_arrays:
            return np.array([], dtype=float)
        arr = np.concatenate(list_of_arrays).astype(float)
        return arr[np.isfinite(arr)]

    def _mae_and_n(list_of_arrays):
        """Mean absolute error + N finite."""
        arr = _concat_finite(list_of_arrays)
        if arr.size == 0:
            return np.nan, 0
        return float(np.mean(arr)), int(arr.size)

    def _pct_le_thresh(list_of_arrays, thresh=ERROR_THRESH_DEG):
        """Percent of absolute errors <= thresh + N finite."""
        arr = _concat_finite(list_of_arrays)
        if arr.size == 0:
            return np.nan, 0
        return float(100.0 * np.mean(arr <= thresh)), int(arr.size)

    # --- per-speed MAEs (you already do this) ---
    m1,  n1  = _mae_and_n(all_first)
    m2s, n2s = _mae_and_n(all_second_self)
    m2x, n2x = _mae_and_n(all_second_cross)

    # --- NEW: per-speed % <= 5° (requested) ---
    p1,  pn1  = _pct_le_thresh(all_first)
    p2x, pn2x = _pct_le_thresh(all_second_cross)

    rows.append({
        "speed": speed_title,

        "MAE 1st (self) [deg]": m1,
        "N 1st": n1,

        "MAE 2nd (self) [deg]": m2s,
        "N 2nd self": n2s,

        "MAE 2nd (cross) [deg]": m2x,
        "N 2nd cross": n2x,

        # NEW columns (only for the two sets you asked for)
        f"% ≤ {ERROR_THRESH_DEG:.1f}° 1st (self)": p1,
        f"N for % 1st": pn1,
        f"% ≤ {ERROR_THRESH_DEG:.1f}° 2nd (cross)": p2x,
        f"N for % 2nd cross": pn2x,
    })

df_speed = pd.DataFrame(rows)

# --- Average of the averages (across speeds) ---
# (mean of per-speed MAEs)
avg_1st_self  = float(df_speed["MAE 1st (self) [deg]"].mean(skipna=True))
avg_2nd_cross = float(df_speed["MAE 2nd (cross) [deg]"].mean(skipna=True))

# NEW: mean of per-speed percentages
avgpct_1st_self  = float(df_speed[f"% ≤ {ERROR_THRESH_DEG:.1f}° 1st (self)"].mean(skipna=True))
avgpct_2nd_cross = float(df_speed[f"% ≤ {ERROR_THRESH_DEG:.1f}° 2nd (cross)"].mean(skipna=True))

# --- NEW: pooled across ALL speeds (optional but usually useful) ---
# pool all finite errors across speeds, then compute pooled MAE and pooled %<=5
all_first_pooled = []
all_second_cross_pooled = []

for speed in speed_tags:
    for p in participants:
        key = (p["name"], speed)
        a1  = results.get(key, {}).get("abs_err_first", np.array([]))
        a2x = results.get(key, {}).get("abs_err_second_cross", np.array([]))
        if a1.size > 0:  all_first_pooled.append(a1)
        if a2x.size > 0: all_second_cross_pooled.append(a2x)

def _pool_stats(list_of_arrays, thresh=ERROR_THRESH_DEG):
    arr = np.concatenate(list_of_arrays).astype(float) if list_of_arrays else np.array([], dtype=float)
    arr = arr[np.isfinite(arr)]
    if arr.size == 0:
        return np.nan, np.nan, 0
    mae = float(np.mean(arr))
    pct = float(100.0 * np.mean(arr <= thresh))
    return mae, pct, int(arr.size)

pooled_mae_1st, pooled_pct_1st, pooled_n_1st = _pool_stats(all_first_pooled)
pooled_mae_2x,  pooled_pct_2x,  pooled_n_2x  = _pool_stats(all_second_cross_pooled)

df_summary = pd.DataFrame([
    {"condition": "1st application (self)",
     "avg of per-speed MAEs [deg]": avg_1st_self,
     f"avg of per-speed % ≤ {ERROR_THRESH_DEG:.1f}°": avgpct_1st_self,
     "pooled MAE [deg]": pooled_mae_1st,
     f"pooled % ≤ {ERROR_THRESH_DEG:.1f}°": pooled_pct_1st,
     "N pooled": pooled_n_1st},

    {"condition": "2nd application (cross)",
     "avg of per-speed MAEs [deg]": avg_2nd_cross,
     f"avg of per-speed % ≤ {ERROR_THRESH_DEG:.1f}°": avgpct_2nd_cross,
     "pooled MAE [deg]": pooled_mae_2x,
     f"pooled % ≤ {ERROR_THRESH_DEG:.1f}°": pooled_pct_2x,
     "N pooled": pooled_n_2x},
])

# Pretty print
pd.set_option("display.precision", 3)
display(df_speed)
display(df_summary)

print(f"Avg of per-speed MAEs — 1st (self):   {avg_1st_self:.3f} deg")
print(f"Avg of per-speed MAEs — 2nd (cross):  {avg_2nd_cross:.3f} deg")
print(f"Avg of per-speed %≤{ERROR_THRESH_DEG:.1f}° — 1st (self):  {avgpct_1st_self:.2f}%")
print(f"Avg of per-speed %≤{ERROR_THRESH_DEG:.1f}° — 2nd (cross): {avgpct_2nd_cross:.2f}%")

print(f"Pooled — 1st (self):  MAE={pooled_mae_1st:.3f} deg, %≤{ERROR_THRESH_DEG:.1f}°={pooled_pct_1st:.2f}%, N={pooled_n_1st}")
print(f"Pooled — 2nd (cross): MAE={pooled_mae_2x:.3f} deg, %≤{ERROR_THRESH_DEG:.1f}°={pooled_pct_2x:.2f}%, N={pooled_n_2x}")
# Out:
#    speed  MAE 1st (self) [deg]  N 1st  MAE 2nd (self) [deg]  N 2nd self  \
# 0   Slow                 6.359   1175                 4.362        1181
# 1   Medm                 5.577   1177                 4.465        1181
# 2   Fast                 6.236   1168                 4.335        1180
# 3  VFast                 5.955   1181                 4.105        1182
# 4   AFAP                 6.043   1180                 4.772        1179
#
#    MAE 2nd (cross) [deg]  N 2nd cross  % ≤ 5.0° 1st (self)  N for % 1st  \
# 0                  3.830         1181               64.681         1175
# 1                  3.383         1181               63.976         1177
# 2                  2.948         1180               65.497         1168
# 3                  3.931         1182               62.066         1181
# 4                  4.883         1179               61.610         1180
#
#    % ≤ 5.0° 2nd (cross)  N for % 2nd cross
# 0                69.179               1181
# ...

# %%
# --- Column 6 (index 5): summary bar plots of mean error per speed ---
# (Keep plots as MAE, but also compute/store RMSE for printing later)

x = np.arange(len(speed_tags))

def _finite(arr):
    arr = np.asarray(arr, dtype=float)
    return arr[np.isfinite(arr)]

def _mae_rmse_from_list(list_of_arrays):
    """Given list of arrays (abs errors), return (mae, rmse, N) over pooled finite values."""
    if not list_of_arrays:
        return np.nan, np.nan, 0
    arr = _finite(np.concatenate(list_of_arrays))
    if arr.size == 0:
        return np.nan, np.nan, 0
    mae  = float(np.mean(arr))
    rmse = float(np.sqrt(np.mean(np.square(arr))))
    return mae, rmse, int(arr.size)

# -----------------------
# Row 1 summary: FIRST set
# -----------------------
ax_sum_first = axes[0, 5]

mean_first = []   # MAE per speed (what you already plot)
rmse_first = []   # RMSE per speed (stored for printing)
n_first    = []   # N pooled per speed (optional but useful)

for speed in speed_tags:
    all_err = []
    for p in participants:
        key = (p["name"], speed)
        abs_err = results.get(key, {}).get("abs_err_first", np.array([]))
        if np.size(abs_err) > 0:
            all_err.append(abs_err)

    mae, rmse, n = _mae_rmse_from_list(all_err)
    mean_first.append(mae)
    rmse_first.append(rmse)
    n_first.append(n)

ax_sum_first.bar(x, mean_first, color="C0")
ax_sum_first.set_xticks(x)
ax_sum_first.set_xticklabels(speed_titles, rotation=45)
ax_sum_first.set_ylabel("Mean abs error (deg)")
ax_sum_first.set_title("1st app mean error vs speed")
ax_sum_first.grid(axis="y", alpha=0.3)

# -----------------------
# Row 2 summary: SECOND set
# -----------------------
ax_sum_second = axes[1, 5]

mean_second_self  = []  # MAE per speed (plotted)
mean_second_cross = []
rmse_second_self  = []  # RMSE per speed (stored)
rmse_second_cross = []
n_second_self     = []  # N pooled per speed (optional)
n_second_cross    = []

for speed in speed_tags:
    all_self  = []
    all_cross = []

    for p in participants:
        key = (p["name"], speed)
        abs_self  = results.get(key, {}).get("abs_err_second",        np.array([]))
        abs_cross = results.get(key, {}).get("abs_err_second_cross",  np.array([]))

        if np.size(abs_self) > 0:
            all_self.append(abs_self)
        if np.size(abs_cross) > 0:
            all_cross.append(abs_cross)

    mae_s, rmse_s, n_s = _mae_rmse_from_list(all_self)
    mae_x, rmse_x, n_x = _mae_rmse_from_list(all_cross)

    mean_second_self.append(mae_s)
    rmse_second_self.append(rmse_s)
    n_second_self.append(n_s)

    mean_second_cross.append(mae_x)
    rmse_second_cross.append(rmse_x)
    n_second_cross.append(n_x)

width = 0.35
ax_sum_second.bar(x - width/2, mean_second_self,  width=width, color="C0", label="self")
ax_sum_second.bar(x + width/2, mean_second_cross, width=width, color="C3", label="xtrain")

ax_sum_second.set_xticks(x)
ax_sum_second.set_xticklabels(speed_titles, rotation=45)
ax_sum_second.set_ylabel("Mean abs error (deg)")
ax_sum_second.set_title("2nd app mean error vs speed")
ax_sum_second.grid(axis="y", alpha=0.3)
ax_sum_second.legend()

plt.tight_layout()
plt.show()

# -----------------------
# Print RMSE (and MAE) per speed
# -----------------------
print("\nPer-speed pooled MAE/RMSE (over participants), FIRST application:")
for title, mae, rmse, n in zip(speed_titles, mean_first, rmse_first, n_first):
    print(f"  {title:5s}: MAE={mae:6.3f}°, RMSE={rmse:6.3f}°, N={n}")

print("\nPer-speed pooled MAE/RMSE (over participants), SECOND application:")
for title, mae_s, rmse_s, n_s, mae_x, rmse_x, n_x in zip(
    speed_titles, mean_second_self, rmse_second_self, n_second_self,
    mean_second_cross, rmse_second_cross, n_second_cross
):
    print(f"  {title:5s}: self  MAE={mae_s:6.3f}°, RMSE={rmse_s:6.3f}°, N={n_s} | "
          f"xtrain MAE={mae_x:6.3f}°, RMSE={rmse_x:6.3f}°, N={n_x}")
# Out:
# Per-speed pooled MAE/RMSE (over participants), FIRST application:
#   Slow : MAE= 6.359°, RMSE=10.172°, N=1175
#   Medm : MAE= 5.577°, RMSE= 8.056°, N=1177
#   Fast : MAE= 6.236°, RMSE= 9.613°, N=1168
#   VFast: MAE= 5.955°, RMSE= 8.839°, N=1181
#   AFAP : MAE= 6.043°, RMSE= 8.211°, N=1180
#
# Per-speed pooled MAE/RMSE (over participants), SECOND application:
#   Slow : self  MAE= 4.362°, RMSE= 5.842°, N=1181 | xtrain MAE= 3.830°, RMSE= 5.314°, N=1181
#   Medm : self  MAE= 4.465°, RMSE= 5.406°, N=1181 | xtrain MAE= 3.383°, RMSE= 4.073°, N=1181
#   Fast : self  MAE= 4.335°, RMSE= 5.413°, N=1180 | xtrain MAE= 2.948°, RMSE= 3.602°, N=1180
#   VFast: self  MAE= 4.105°, RMSE= 5.469°, N=1182 | xtrain MAE= 3.931°, RMSE= 5.265°, N=1182
#   AFAP : self  MAE= 4.772°, RMSE= 9.463°, N=1179 | xtrain MAE= 4.883°, RMSE= 9.667°, N=1179

# %%
# -----------------------
# ONE number per application (across all speeds + participants)
# and ONE number across applications
# -----------------------

def _pool_all_errors(results, participants, speed_tags, key_name):
    """
    key_name: 'abs_err_first', 'abs_err_second', or 'abs_err_second_cross'
    Returns pooled finite abs errors as a 1D float array.
    """
    pooled = []
    for speed in speed_tags:
        for p in participants:
            key = (p["name"], speed)
            arr = results.get(key, {}).get(key_name, np.array([]))
            if np.size(arr) > 0:
                pooled.append(np.asarray(arr, dtype=float))
    if not pooled:
        return np.array([], dtype=float)
    pooled = np.concatenate(pooled).astype(float)
    pooled = pooled[np.isfinite(pooled)]
    return pooled

def _mae_rmse(arr):
    if arr.size == 0:
        return np.nan, np.nan, 0
    mae  = float(np.mean(arr))
    rmse = float(np.sqrt(np.mean(np.square(arr))))
    return mae, rmse, int(arr.size)

# --- POOLED (recommended): weights by number of samples ---
pooled_first = _pool_all_errors(results, participants, speed_tags, "abs_err_first")
pooled_self2 = _pool_all_errors(results, participants, speed_tags, "abs_err_second")
pooled_x2    = _pool_all_errors(results, participants, speed_tags, "abs_err_second_cross")

mae_first, rmse_first_all, n_first_all = _mae_rmse(pooled_first)
mae_self2, rmse_self2_all, n_self2_all = _mae_rmse(pooled_self2)
mae_x2,    rmse_x2_all,    n_x2_all    = _mae_rmse(pooled_x2)

print("\nPOOLED across speeds+participants:")
print(f"  1st app (self):   MAE={mae_first:.3f}°, RMSE={rmse_first_all:.3f}°, N={n_first_all}")
print(f"  2nd app (self):   MAE={mae_self2:.3f}°, RMSE={rmse_self2_all:.3f}°, N={n_self2_all}")
print(f"  2nd app (xtrain): MAE={mae_x2:.3f}°, RMSE={rmse_x2_all:.3f}°, N={n_x2_all}")

# --- Optional: "equal-weight across speeds" version (mean of per-speed values) ---
# These ignore per-speed N differences.
mean_of_speed_mae_first = float(np.nanmean(mean_first))
mean_of_speed_rmse_first = float(np.nanmean(rmse_first))

mean_of_speed_mae_self2 = float(np.nanmean(mean_second_self))
mean_of_speed_rmse_self2 = float(np.nanmean(rmse_second_self))

mean_of_speed_mae_x2 = float(np.nanmean(mean_second_cross))
mean_of_speed_rmse_x2 = float(np.nanmean(rmse_second_cross))

print("\nMEAN-OF-SPEEDS (each speed equally weighted):")
print(f"  1st app (self):   MAE={mean_of_speed_mae_first:.3f}°, RMSE={mean_of_speed_rmse_first:.3f}°")
print(f"  2nd app (self):   MAE={mean_of_speed_mae_self2:.3f}°, RMSE={mean_of_speed_rmse_self2:.3f}°")
print(f"  2nd app (xtrain): MAE={mean_of_speed_mae_x2:.3f}°, RMSE={mean_of_speed_rmse_x2:.3f}°")

# --- ONE number across applications ---
# You need to decide what "across applications" means.

# (A) Combine 1st app (self) + 2nd app (self) into one pooled "self across applications"
pooled_self_both = np.concatenate([pooled_first, pooled_self2]) if (pooled_first.size + pooled_self2.size) else np.array([], float)
mae_self_both, rmse_self_both, n_self_both = _mae_rmse(pooled_self_both)
print("\nAcross applications (SELF only: 1st+self + 2nd+self pooled):")
print(f"  SELF both apps:   MAE={mae_self_both:.3f}°, RMSE={rmse_self_both:.3f}°, N={n_self_both}")

# (B) Combine 1st app (self) + 2nd app (xtrain) into one pooled "overall across applications"
pooled_overall = np.concatenate([pooled_first, pooled_x2]) if (pooled_first.size + pooled_x2.size) else np.array([], float)
mae_overall, rmse_overall, n_overall = _mae_rmse(pooled_overall)
print("\nAcross applications (1st self + 2nd xtrain pooled):")
print(f"  OVERALL:          MAE={mae_overall:.3f}°, RMSE={rmse_overall:.3f}°, N={n_overall}")

# (C) If you literally want to average the two single numbers (equal-weight apps),
# use the mean of the two pooled metrics (not pooling raw errors):
mae_avg_apps = float(np.nanmean([mae_first, mae_self2]))
rmse_avg_apps = float(np.nanmean([rmse_first_all, rmse_self2_all]))
print("\nEqual-weight average of application-level pooled metrics (1st self & 2nd self):")
print(f"  avg apps:         MAE={mae_avg_apps:.3f}°, RMSE={rmse_avg_apps:.3f}°")
# Out:
# POOLED across speeds+participants:
#   1st app (self):   MAE=6.033°, RMSE=9.013°, N=5881
#   2nd app (self):   MAE=4.407°, RMSE=6.512°, N=5903
#   2nd app (xtrain): MAE=3.795°, RMSE=5.981°, N=5903
#
# MEAN-OF-SPEEDS (each speed equally weighted):
#   1st app (self):   MAE=6.034°, RMSE=8.978°
#   2nd app (self):   MAE=4.408°, RMSE=6.319°
#   2nd app (xtrain): MAE=3.795°, RMSE=5.584°
#
# Across applications (SELF only: 1st+self + 2nd+self pooled):
#   SELF both apps:   MAE=5.219°, RMSE=7.860°, N=11784
#
# Across applications (1st self + 2nd xtrain pooled):
#   OVERALL:          MAE=4.912°, RMSE=7.646°, N=11784
#
# Equal-weight average of application-level pooled metrics (1st self & 2nd self):
#   avg apps:         MAE=5.220°, RMSE=7.763°

# %%
# -------------------------------------------------
# Threshold sweep: % of errors ≤ θ (θ = 1° … 15°)
# Combined across 1st (self) + 2nd (cross)
# -------------------------------------------------

THRESHOLDS = np.arange(1.0, 16.0, 1.0)  # 1°, 2°, ..., 15°

# -------------------------------------------------
# Collect pooled errors across ALL speeds + participants
# -------------------------------------------------
all_first_pooled = []
all_second_cross_pooled = []

for speed in speed_tags:
    for p in participants:
        key = (p["name"], speed)

        a1  = results.get(key, {}).get("abs_err_first", np.array([]))
        a2x = results.get(key, {}).get("abs_err_second_cross", np.array([]))

        if np.size(a1) > 0:
            all_first_pooled.append(np.asarray(a1, dtype=float))
        if np.size(a2x) > 0:
            all_second_cross_pooled.append(np.asarray(a2x, dtype=float))

def _finite_concat(list_of_arrays):
    if not list_of_arrays:
        return np.array([], dtype=float)
    arr = np.concatenate(list_of_arrays).astype(float)
    return arr[np.isfinite(arr)]

def _pct_le(arr, thr):
    arr = np.asarray(arr, dtype=float)
    arr = arr[np.isfinite(arr)]
    return np.nan if arr.size == 0 else float(100.0 * np.mean(arr <= thr))

# -------------------------------------------------
# Pooled arrays
# -------------------------------------------------
first_errs = _finite_concat(all_first_pooled)
cross_errs = _finite_concat(all_second_cross_pooled)

both_errs = (
    np.concatenate([first_errs, cross_errs])
    if (first_errs.size + cross_errs.size) > 0
    else np.array([], dtype=float)
)

print(f"N pooled 1st (self)         = {first_errs.size}")
print(f"N pooled 2nd (cross)        = {cross_errs.size}")
print(f"N pooled BOTH (1st + 2ndx)  = {both_errs.size}")

# -------------------------------------------------
# ONE pooled curve: % ≤ θ across BOTH conditions
# -------------------------------------------------
print("\nPOOLED across 1st(self) + 2nd(cross):")
rows_pooled = []

for thr in THRESHOLDS:
    pct = _pct_le(both_errs, thr)
    rows_pooled.append({
        "threshold_deg": thr,
        "pct_le": pct,
        "N": both_errs.size
    })
    print(f"  % ≤ {thr:2.0f}° : {pct:6.2f}%")

df_pooled_curve = pd.DataFrame(rows_pooled)

# -------------------------------------------------
# Per-speed threshold sweep
# -------------------------------------------------
rows_both_pct = []

for speed, speed_title in zip(speed_tags, speed_titles):

    first_list = []
    cross_list = []

    for p in participants:
        key = (p["name"], speed)
        a1  = results.get(key, {}).get("abs_err_first", np.array([]))
        a2x = results.get(key, {}).get("abs_err_second_cross", np.array([]))
        if np.size(a1) > 0:  first_list.append(np.asarray(a1, dtype=float))
        if np.size(a2x) > 0: cross_list.append(np.asarray(a2x, dtype=float))

    first_speed = _finite_concat(first_list)
    cross_speed = _finite_concat(cross_list)
    both_speed  = (
        np.concatenate([first_speed, cross_speed])
        if (first_speed.size + cross_speed.size) > 0
        else np.array([], dtype=float)
    )

    row = {"speed": speed_title}
    for thr in THRESHOLDS:
        row[f"% ≤ {thr:.0f}°"] = _pct_le(both_speed, thr)

    rows_both_pct.append(row)

df_both_pct = pd.DataFrame(rows_both_pct)

# -------------------------------------------------
# Average across speeds (one number per angle)
# -------------------------------------------------
rows_avg = []

for thr in THRESHOLDS:
    col = f"% ≤ {thr:.0f}°"
    rows_avg.append({
        "threshold_deg": thr,
        "avg_pct_across_speeds": float(df_both_pct[col].mean(skipna=True))
    })

df_avg_curve = pd.DataFrame(rows_avg)

# -------------------------------------------------
# Display tables
# -------------------------------------------------
display(df_both_pct)
display(df_avg_curve)

print("\nAVG across speeds (1st+self + 2nd+cross):")
for _, r in df_avg_curve.iterrows():
    print(f"  % ≤ {r['threshold_deg']:2.0f}° : {r['avg_pct_across_speeds']:6.2f}%")
# Out:
# N pooled 1st (self)         = 5881
# N pooled 2nd (cross)        = 5903
# N pooled BOTH (1st + 2ndx)  = 11784
#
# POOLED across 1st(self) + 2nd(cross):
#   % ≤  1° :  17.38%
#   % ≤  2° :  33.63%
#   % ≤  3° :  47.90%
#   % ≤  4° :  60.12%
#   % ≤  5° :  68.67%
#   % ≤  6° :  75.02%
#   % ≤  7° :  79.74%
#   % ≤  8° :  83.04%
#   % ≤  9° :  85.73%
#   % ≤ 10° :  88.08%
#   % ≤ 11° :  89.77%
#   % ≤ 12° :  91.02%
#   % ≤ 13° :  91.97%
#   % ≤ 14° :  92.79%
#   % ≤ 15° :  93.64%
#    speed  % ≤ 1°  % ≤ 2°  % ≤ 3°  % ≤ 4°  % ≤ 5°  % ≤ 6°  % ≤ 7°  % ≤ 8°  \
# 0   Slow  21.350  35.739  49.278  60.908  66.935  72.496  79.160  83.192
# 1   Medm  14.207  30.831  47.328  59.500  70.865  79.601  84.266  86.938
# 2   Fast  16.865  33.348  49.532  63.714  75.852  81.729  84.966  87.053
# 3  VFast  19.551  35.548  48.074  58.612  65.468  72.281  76.894  80.745
# 4   AFAP  14.922  32.683  45.273  57.864  64.265  69.012  73.421  77.279
#
# ...

# %%
def min_threshold_for_target_pct(errs, target_pct=90.0, step_deg=1.0, max_deg=90.0):
    """
    Return the smallest threshold (deg) such that >= target_pct of errs are <= threshold.
    Increments by step_deg until max_deg.
    """
    arr = np.asarray(errs, dtype=float)
    arr = arr[np.isfinite(arr)]
    if arr.size == 0:
        return np.nan, np.nan, 0  # threshold, achieved_pct, N

    thr = 0.0
    while thr <= max_deg + 1e-9:
        achieved = 100.0 * np.mean(arr <= thr)
        if achieved >= target_pct:
            return thr, achieved, int(arr.size)
        thr += step_deg

    # If not reached within max_deg
    return np.nan, 100.0 * np.mean(arr <= max_deg), int(arr.size)

TARGET_PCT = 90.0

thr, achieved, N = min_threshold_for_target_pct(both_errs, target_pct=TARGET_PCT, step_deg=1.0, max_deg=90.0)

if np.isfinite(thr):
    print(f"Smallest threshold with ≥{TARGET_PCT:.0f}% of errors ≤ threshold: {thr:.0f}° "
          f"(achieved {achieved:.2f}%, N={N})")
else:
    print(f"Did not reach ≥{TARGET_PCT:.0f}% within 0–90°. Achieved {achieved:.2f}% at 90° (N={N}).")
# Out:
# Smallest threshold with ≥90% of errors ≤ threshold: 12° (achieved 91.02%, N=11784)

# %%
TARGET_PCT = 95.0

if both_errs.size == 0:
    print("No pooled errors found; cannot compute 95% threshold.")
else:
    # --- Exact 95th percentile threshold (recommended) ---
    thr95 = float(np.percentile(both_errs, TARGET_PCT))
    achieved95 = 100.0 * np.mean(both_errs <= thr95)
    print(f"BOTH pooled: {TARGET_PCT:.0f}th percentile threshold = {thr95:.2f}° "
          f"(captures {achieved95:.2f}% of predictions)")

    # --- Optional: integer-degree threshold (1° increments) ---
    thr_int = None
    for t in range(0, 91):   # search 0..90°
        if 100.0 * np.mean(both_errs <= t) >= TARGET_PCT:
            thr_int = t
            break

    if thr_int is not None:
        achieved_int = 100.0 * np.mean(both_errs <= thr_int)
        print(f"BOTH pooled: smallest integer threshold achieving ≥{TARGET_PCT:.0f}% is {thr_int}° "
              f"(captures {achieved_int:.2f}%)")
    else:
        achieved_90 = 100.0 * np.mean(both_errs <= 90.0)
        print(f"BOTH pooled: did not reach {TARGET_PCT:.0f}% within 0–90°. "
              f"At 90° captures {achieved_90:.2f}%.")
# Out:
# BOTH pooled: 95th percentile threshold = 16.86° (captures 94.99% of predictions)
# BOTH pooled: smallest integer threshold achieving ≥95% is 17° (captures 95.09%)

# %% [markdown]
# ## Stat Analysis
#
# (1) Does speed affect MAE?  Linear Mixed Affects Model ->   Participant and speed
#
# mae ij ~ speed_idx ij + (1 | participant j) -> participant j and speed i
#
# A linear mixed-effects model was used to assess the effect of speed on angular error, with sped treated as a fixed effect and participant modeled as a random intercept to account for repeated measures within subjects.

# %%
rows = []

for p in participants:
    pname = p["name"]
    for speed, speed_title in zip(speed_tags, speed_titles):
        key = (pname, speed)

        def _mean_or_nan(arr):
            return float(np.nanmean(arr)) if arr.size else np.nan

        rows.append({
            "participant": pname,
            "speed": speed_title,
            "speed_idx": speed_tags.index(speed),  # for trend tests
            "mae_1st_self":  _mean_or_nan(results.get(key, {}).get("abs_err_first", np.array([]))),
            "mae_2nd_self":  _mean_or_nan(results.get(key, {}).get("abs_err_second", np.array([]))),
            "mae_2nd_cross": _mean_or_nan(results.get(key, {}).get("abs_err_second_cross", np.array([]))),
        })

df_lme = pd.DataFrame(rows)
display(df_lme)
# Out:
#    participant  speed  speed_idx  mae_1st_self  mae_2nd_self  mae_2nd_cross
# 0           P1   Slow          0         4.305         5.249          4.963
# 1           P1   Medm          1         5.089         4.943          3.571
# 2           P1   Fast          2         5.157         5.192          3.575
# 3           P1  VFast          3         6.112         5.965          5.766
# 4           P1   AFAP          4         7.902         4.571          3.361
# 5           P2   Slow          0         8.479         3.440          3.608
# 6           P2   Medm          1         5.107         3.638          3.958
# 7           P2   Fast          2         4.496         2.806          2.853
# 8           P2  VFast          3         3.392         2.629          3.259
# 9           P2   AFAP          4         4.005         6.589          7.343
# 10          P3   Slow          0         6.323         4.390          2.915
# ...

# %%
df_long = df_lme.melt(
    id_vars=["participant", "speed", "speed_idx"],
    value_vars=["mae_1st_self", "mae_2nd_self", "mae_2nd_cross"],
    var_name="condition",
    value_name="mae"
).dropna()

display(df_long)
# Out:
#    participant  speed  speed_idx      condition    mae
# 0           P1   Slow          0   mae_1st_self  4.305
# 1           P1   Medm          1   mae_1st_self  5.089
# 2           P1   Fast          2   mae_1st_self  5.157
# 3           P1  VFast          3   mae_1st_self  6.112
# 4           P1   AFAP          4   mae_1st_self  7.902
# 5           P2   Slow          0   mae_1st_self  8.479
# 6           P2   Medm          1   mae_1st_self  5.107
# 7           P2   Fast          2   mae_1st_self  4.496
# 8           P2  VFast          3   mae_1st_self  3.392
# 9           P2   AFAP          4   mae_1st_self  4.005
# 10          P3   Slow          0   mae_1st_self  6.323
# 11          P3   Medm          1   mae_1st_self  6.529
# 12          P3   Fast          2   mae_1st_self  8.989
# 13          P3  VFast          3   mae_1st_self  8.347
# 14          P3   AFAP          4   mae_1st_self  6.208
# 15          P1   Slow          0   mae_2nd_self  5.249
# ...

# %%
model = smf.mixedlm(
    "mae ~ speed_idx",
    df_long,
    groups=df_long["participant"]
)
result = model.fit(reml=True)
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 model = smf.mixedlm(
#       2     "mae ~ speed_idx",
#       3     df_long,
#       4     groups=df_long["participant"]
#       5 )
#       6 result = model.fit(reml=True)
#       7 print(result.summary())
#
# NameError: name 'smf' is not defined

# %% [markdown]
# ## Compare self-trained 1st application vs 2nd application (blue bars) across speeds and participants.  Already showed that speed does not affect MAE

# %%
from scipy.stats import ttest_rel

# -----------------------------
# Build participant-level means
# -----------------------------
rows = []

for p in participants:
    p_name = p["name"]

    a1_all = []   # 1st app self errors across all speeds
    a2s_all = []  # 2nd app self errors across all speeds

    for speed in speed_tags:
        key = (p_name, speed)

        a1  = results.get(key, {}).get("abs_err_first",  np.array([]))
        a2s = results.get(key, {}).get("abs_err_second", np.array([]))

        if isinstance(a1, list):  a1 = np.asarray(a1)
        if isinstance(a2s, list): a2s = np.asarray(a2s)

        if a1.size > 0:
            a1_all.append(a1[np.isfinite(a1)])
        if a2s.size > 0:
            a2s_all.append(a2s[np.isfinite(a2s)])

    # concatenate across speeds, then average -> one MAE per participant per condition
    mae_1st = float(np.nanmean(np.concatenate(a1_all))) if a1_all else np.nan
    mae_2nd = float(np.nanmean(np.concatenate(a2s_all))) if a2s_all else np.nan

    rows.append({"participant": p_name, "mae_1st_self": mae_1st, "mae_2nd_self": mae_2nd})

df_p = pd.DataFrame(rows)
display(df_p)

# -----------------------------
# Paired t-test across participants
# -----------------------------
df_paired = df_p.dropna(subset=["mae_1st_self", "mae_2nd_self"]).copy()
print("Paired participants:", len(df_paired), "/", len(df_p))

if len(df_paired) >= 2:
    t, p = ttest_rel(df_paired["mae_1st_self"], df_paired["mae_2nd_self"])
    delta = df_paired["mae_2nd_self"] - df_paired["mae_1st_self"]

    print(f"Paired t-test (1st self vs 2nd self): t({len(df_paired)-1}) = {t:.3f}, p = {p:.4f}")
    print(f"Mean Δ (2nd − 1st) = {delta.mean():.3f} deg")
else:
    print("Not enough paired participant-level data to run the test.")

# %% [markdown]
# ## Compare 2nd application (blue bars) vs 2nd application (red bars) across speeds and participants.  Already showed that speed does not affect MAE

# %%
rows = []

for p in participants:
    pname = p["name"]

    # collect per-speed MAEs for this participant
    mae_self_2nd  = []
    mae_cross_2nd = []

    for speed in speed_tags:
        key = (pname, speed)

        a2s = results.get(key, {}).get("abs_err_second", np.array([]))
        a2x = results.get(key, {}).get("abs_err_second_cross", np.array([]))

        if a2s.size > 0:
            mae_self_2nd.append(np.nanmean(a2s))
        if a2x.size > 0:
            mae_cross_2nd.append(np.nanmean(a2x))

    # average across speeds (participant-level)
    rows.append({
        "participant": pname,
        "mae_2nd_self":  np.mean(mae_self_2nd),
        "mae_2nd_cross": np.mean(mae_cross_2nd),
        "delta_cross_minus_self": np.mean(mae_cross_2nd) - np.mean(mae_self_2nd)
    })

df_cmp = pd.DataFrame(rows)
display(df_cmp)

# paired test across participants
t, p = ttest_rel(df_cmp["mae_2nd_self"], df_cmp["mae_2nd_cross"])

print(f"Paired participants: {len(df_cmp)}")
print(f"Paired t-test (2nd self vs 2nd cross): t({len(df_cmp)-1}) = {t:.3f}, p = {p:.4g}")

# %%
calib_result = cam.calibrate_trials_with_camera(
    adc_trials_first,
    adc_trials_second,
    adc_column="adc_ch3",
    poly_order=2,
    calib_kwargs={
        "adc_column": "adc_ch3",
        "plot_all_data": False,
        "exclude_sets": (),  # keep 1 & 2 so set==2 is the orange SECOND
    },
)
calib_df = calib_result["calib_df"]

# %%
speed_title_map = {
    "slow": "Slow",
    "medm": "Med",
    "fast": "Fast",
    "vfas": "VFast",
    "afap": "AFAP",
}


fig, axes = cam.plot_adc_abs_error_summary_grid(
    results,
    speed_titles=speed_title_map,
    speed_order=speed_tags,
    dlc_angle_col=("metric", "mcp_bend_deg", "deg"),
    adc_angle_col="theta_cam_cal_adc",

    # Row 1: P3, B2_slow, trial 0
    example1_participant="P3",
    example1_speed="slow",
    example1_trial_idx=0,
    example1_df=example1_df,

    # Row 2: P3, B2_vfas, trial 1
    example2_participant="P3",
    example2_speed="vfas",
    example2_trial_idx=1,
    example2_df=example2_df,

    # NEW: calibration data (SECOND set, orange)
    calib_df=calib_df,
    calib_set_label=2,

    example_col_start=2,        # TS/box in cols 3 & 4; calib in col 2
    abs_err_ylim_examples=(0, 20),
    abs_err_ylim_summary=(0, 35),
    boxplot_wspace=0.1,
    example_col_gap_scale=7,
    bar_gap_from_afap=0.05,
    calib_x_shift=0.1,   # try 0.05, tune to taste

    exclude_participant_set_for_summary=[("P4", "FIRST")],
)

# %%
fig, axes = cam.plot_adc_abs_error_summary_grid(
    results,
    speed_titles=speed_title_map,
    speed_order=speed_tags,
    dlc_angle_col=("metric", "mcp_bend_deg", "deg"),
    adc_angle_col="theta_cam_cal_adc",
    exclude_participant_set_for_summary=[("P4", "FIRST")],
)
