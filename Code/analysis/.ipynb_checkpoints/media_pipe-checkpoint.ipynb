# %%
import sys
# !{sys.executable} -m pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\toppe\anaconda3\lib\site-packages (0.10.21)
# Requirement already satisfied: absl-py in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: numpy<2 in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\toppe\anaconda3\lib\site-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\toppe\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\toppe\anaconda3\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\toppe\anaconda3\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\toppe\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\toppe\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\toppe\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\toppe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
import mediapipe as mp
print("mediapipe version:", mp.__version__)
# Out:
# mediapipe version: 0.10.21

# %%
import os, urllib.request
import numpy as np
import cv2
import matplotlib.pyplot as plt

import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

print("mediapipe version:", mp.__version__)

# Hand Landmarker model (Tasks API)
MODEL_URL  = "https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task"
MODEL_DIR  = r"C:\models"                      # <- change if you want
MODEL_PATH = os.path.join(MODEL_DIR, "hand_landmarker.task")
os.makedirs(MODEL_DIR, exist_ok=True)

# Download the model if missing
if not os.path.exists(MODEL_PATH):
    print("Downloading model…")
    urllib.request.urlretrieve(MODEL_URL, MODEL_PATH)
    print("Saved:", MODEL_PATH)
else:
    print("Model present:", MODEL_PATH)
# Out:
# mediapipe version: 0.10.21
# Downloading model…
# Saved: C:\models\hand_landmarker.task

# %%
# EDIT THIS to your actual file (include .png/.jpg/.jpeg etc.)
IMAGE_PATH = r"C:\flir_capture\calibration\tom_hand_media_pipe\tom_hand.jpg"

assert os.path.exists(IMAGE_PATH), f"Image not found: {IMAGE_PATH}"

# Create the mp.Image directly from file (avoids path issues with cv2)
mp_image = mp.Image.create_from_file(IMAGE_PATH)

# For drawing with OpenCV/matplotlib, get a NumPy RGB view
img_rgb = mp_image.numpy_view()
print("Image shape (H, W, C):", img_rgb.shape)
# Out:
# Image shape (H, W, C): (480, 640, 3)

# %%
base_options = python.BaseOptions(model_asset_path=MODEL_PATH)
options = vision.HandLandmarkerOptions(
    base_options=base_options,
    num_hands=2,                          # detect up to 2 hands
    min_hand_detection_confidence=0.5,
    min_hand_presence_confidence=0.5,
    min_tracking_confidence=0.5
)

detector = vision.HandLandmarker.create_from_options(options)
result = detector.detect(mp_image)

num_hands = 0 if not result.hand_landmarks else len(result.hand_landmarks)
print("Hands detected:", num_hands)
# Out:
# Hands detected: 1

# %%
# Minimal MediaPipe hand topology (21-pt) connection list
HAND_CONNECTIONS = [
    (0,1),(1,2),(2,3),(3,4),          # Thumb
    (0,5),(5,6),(6,7),(7,8),          # Index
    (5,9),(9,10),(10,11),(11,12),     # Middle
    (9,13),(13,14),(14,15),(15,16),   # Ring
    (13,17),(17,18),(18,19),(19,20),  # Pinky
    (0,17)                             # Palm edge
]

# Copy image for drawing (OpenCV expects BGR)
draw_bgr = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)
h, w, _ = draw_bgr.shape

if result.hand_landmarks:
    for hand in result.hand_landmarks:
        pts = [(int(lm.x * w), int(lm.y * h)) for lm in hand]

        # Draw connections
        for i, j in HAND_CONNECTIONS:
            if 0 <= i < len(pts) and 0 <= j < len(pts):
                cv2.line(draw_bgr, pts[i], pts[j], (255, 0, 0), 2)

        # Draw landmarks
        for x, y in pts:
            cv2.circle(draw_bgr, (x, y), 4, (0, 255, 0), -1)
else:
    print("No hands found. Try a larger/clearer hand region.")

# Show with matplotlib (convert back to RGB)
plt.imshow(cv2.cvtColor(draw_bgr, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Hand landmarks (MediaPipe 0.10.21 Tasks API)")
plt.show()

# %%
if result.hand_landmarks:
    first_hand = result.hand_landmarks[0]     # 21 landmarks
    coords = np.array([[lm.x, lm.y, lm.z] for lm in first_hand])  # normalized coords
    print("First hand landmarks (21 x 3: x,y,z in [0..1] image coords):")
    print(coords)
else:
    print("No landmarks available.")
# Out:
# First hand landmarks (21 x 3: x,y,z in [0..1] image coords):
# [[ 5.04619360e-01  9.71487164e-01  1.44666342e-06]
#  [ 5.97561121e-01  8.05088043e-01 -8.95822495e-02]
#  [ 6.06724262e-01  6.20972395e-01 -1.01396769e-01]
#  [ 5.95144391e-01  4.70974118e-01 -8.37962851e-02]
#  [ 5.65960884e-01  3.44340533e-01 -5.38335852e-02]
#  [ 3.59412611e-01  5.86951375e-01 -5.13976440e-02]
#  [ 3.66825402e-01  3.85508657e-01 -9.59701743e-03]
#  [ 4.10873681e-01  3.13623399e-01  2.75963768e-02]
#  [ 4.46447462e-01  2.89208978e-01  5.45201674e-02]
#  [ 2.96671569e-01  6.27129614e-01  1.85613297e-02]
#  [ 2.90182889e-01  4.06626105e-01  5.49754016e-02]
#  [ 3.45908403e-01  3.31612468e-01  7.83699229e-02]
#  [ 4.01035964e-01  3.14639509e-01  9.67943072e-02]
#  [ 2.72979617e-01  6.67537987e-01  8.63069221e-02]
#  [ 2.55811304e-01  4.76240486e-01  1.18961543e-01]
#  [ 3.05486590e-01  3.94185364e-01  1.26304314e-01]
#  [ 3.52762282e-01  3.59694958e-01  1.30411476e-01]
#  [ 2.78570533e-01  6.97895050e-01  1.48000151e-01]
#  [ 2.50068843e-01  5.49893200e-01  1.69499591e-01]
#  [ 2.75499225e-01  4.74494666e-01  1.72883943e-01]
#  [ 3.10780376e-01  4.31727171e-01  1.77220672e-01]]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import path_to_repository
from analysis import DLC3DBendAngles
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from config import path_to_repository
#       2 from analysis import DLC3DBendAngles
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'config'
